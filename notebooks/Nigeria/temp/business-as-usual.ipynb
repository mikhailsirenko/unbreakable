# %%
# conflict intensity vs difference in consumption loss
# conflict intensity vs consumption_loss_With_conflict
# consumption per capita vs consumption_loss_with_conflict

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import geopandas as gpd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
from ema_workbench import load_results
from unbreakable.analysis.analyzer import *
from unbreakable.analysis.visualizer import *
sns.set_theme(style="ticks")

# %%
# Specify the country, return period, and number of scenarios and policies
country = 'Nigeria'
return_period = 100
n_scenarios = 250
n_policies = 0

# Load the results and prepare the outcomes
results = load_results(f'../../experiments/{country}/return_period={return_period}, scenarios={n_scenarios}, policies={n_policies}, conflict=True.tar.gz')
conflict = prepare_outcomes(results, add_uncertainties=False, add_policies=False)

results = load_results(f'../../experiments/{country}/return_period={return_period}, scenarios={n_scenarios}, policies={n_policies}.tar.gz')
no_conflict = prepare_outcomes(results, add_uncertainties=False, add_policies=False)

# Load conflict impact data
conflict_impact = pd.read_csv(f'../../data/processed/conflict/Nigeria.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 9
#       7 # Load the results and prepare the outcomes
#       8 results = load_results(f'../../experiments/{country}/return_period={return_period}, scenarios={n_scenarios}, policies={n_policies}, conflict=True.tar.gz')
# ----> 9 conflict = prepare_outcomes(results, add_uncertainties=False, add_policies=False)
#      11 results = load_results(f'../../experiments/{country}/return_period={return_period}, scenarios={n_scenarios}, policies={n_policies}.tar.gz')
#      12 no_conflict = prepare_outcomes(results, add_uncertainties=False, add_policies=False)
#
# File c:\users\mikhail\my drive\0 code\unbreakable\unbreakable\analysis\analyzer.py:139, in prepare_outcomes(results, add_policies, add_uncertainties)
#     137 for v, name in zip(arr, outcome_names):
#     138     if name in ['weighted_vuln_quint', 'weighted_vuln_dec', 'years_in_poverty']:
# --> 139         outcomes[i, l] = ast.literal_eval(v)
#     140     else:
#     141         outcomes[i, l] = v
#
# File c:\Users\Mikhail\miniconda3\envs\unbreakable\lib\ast.py:105, in literal_eval(node_or_string)
#     103                 return left - right
#     104     return _convert_signed_num(node)
# --> 105 return _convert(node_or_string)
#
# File c:\Users\Mikhail\miniconda3\envs\unbreakable\lib\ast.py:104, in literal_eval.<locals>._convert(node)
#     102         else:
#     103             return left - right
# --> 104 return _convert_signed_num(node)
#
# File c:\Users\Mikhail\miniconda3\envs\unbreakable\lib\ast.py:78, in literal_eval.<locals>._convert_signed_num(node)
#      76     else:
#      77         return - operand
# ---> 78 return _convert_num(node)
#
# File c:\Users\Mikhail\miniconda3\envs\unbreakable\lib\ast.py:69, in literal_eval.<locals>._convert_num(node)
#      67 def _convert_num(node):
#      68     if not isinstance(node, Constant) or type(node.value) not in (int, float, complex):
# ---> 69         _raise_malformed_node(node)
#      70     return node.value
#
# File c:\Users\Mikhail\miniconda3\envs\unbreakable\lib\ast.py:66, in literal_eval.<locals>._raise_malformed_node(node)
#      65 def _raise_malformed_node(node):
# ---> 66     raise ValueError(f'malformed node or string: {node!r}')
#
# ValueError: malformed node or string: 301.06823873415584

# %%
columns_of_interest = ['n_aff_people', 'n_aff_households', 'tot_consum_loss_npv', 'annual_avg_consum_loss_pct', 'mean_recovery_rate', 'r']
no_conflict_grouped = no_conflict.groupby('region').mean(numeric_only=True)[columns_of_interest]
conflict_grouped = conflict.groupby('region').mean(numeric_only=True)[columns_of_interest]
delta = no_conflict_grouped - conflict_grouped
delta = delta.merge(conflict_impact[['region', 'New bins']], left_index=True, right_on='region')
delta.sort_values('New bins', inplace=True, ascending=False)
delta.set_index('region', inplace=True)
delta
# Out:
#                                  n_aff_people  n_aff_households  \
# region
# Borno                              904.975371             0.472
# Nasarawa                           -14.136017            -0.012
# Adamawa                           -665.816004             0.992
# Taraba                            -371.825686             1.040
# Bayelsa                           -279.153347             1.052
# Benue                              511.276775            -0.236
# Plateau                             22.380516            -0.112
# Yobe                              -598.132297            -0.640
# Rivers                           -1040.532372             0.084
# Abuja Federal Capital Territory     38.750035            -0.044
# Cross River                       -447.924944            -0.828
# Delta                            -1358.527309            -0.232
# Lagos                            -1832.812734            -0.528
# Abia                               107.484890             0.224
# Ondo                               275.687799             0.124
# Osun                                21.975486            -0.092
# Kogi                              -916.278485            -0.124
# Kaduna                             -33.235660            -0.008
# Zamfara                            201.117433             0.156
# Edo                               -138.352490            -0.184
# Anambra                            132.565443             0.860
# Gombe                              142.589138             0.068
# Enugu                              115.866207            -0.028
# Ebonyi                            -377.130506            -0.544
# Ekiti                             -159.197762             0.044
# Akwa Ibom                         1128.436718             0.848
# Sokoto                             904.896090            -0.052
# Bauchi                            -357.680371             0.056
# Oyo                                -19.845784             0.048
# Jigawa                            -864.145066            -0.896
# Kano                               119.119459             0.224
# Niger                              482.902744            -0.188
# Kwara                             -221.001536            -0.096
# Imo                                357.847124            -0.500
# Kebbi                              354.169756             0.132
# Katsina                           -397.868841            -0.416
# Ogun                              -127.510054             0.068
#
#                                  tot_consum_loss_npv  \
# region
# Borno                                   4.258634e+07
# Nasarawa                                6.046270e+06
# Adamawa                                 4.980892e+07
# Taraba                                  5.722800e+07
# Bayelsa                                 3.166758e+06
# Benue                                   2.104046e+07
# Plateau                                 2.342235e+06
# Yobe                                    1.390535e+07
# Rivers                                 -2.725308e+07
# Abuja Federal Capital Territory        -8.338826e+04
# Cross River                             1.172693e+07
# Delta                                   1.066902e+06
# Lagos                                  -9.032684e+06
# Abia                                   -1.719202e+05
# Ondo                                    1.531219e+06
# Osun                                   -7.756289e+04
# Kogi                                   -9.611329e+05
# Kaduna                                 -7.666020e+04
# Zamfara                                 2.889978e+06
# Edo                                     1.023158e+05
# Anambra                                -4.967069e+06
# Gombe                                   5.546032e+05
# Enugu                                  -1.832321e+05
# Ebonyi                                  7.337742e+05
# Ekiti                                   2.862563e+04
# Akwa Ibom                              -1.794031e+06
# Sokoto                                  1.048134e+06
# Bauchi                                  3.824835e+05
# Oyo                                    -2.701598e+05
# Jigawa                                  2.744928e+06
# Kano                                   -2.718317e+04
# Niger                                   1.279644e+05
# Kwara                                   1.003454e+05
# Imo                                    -1.022123e+07
# Kebbi                                   2.538371e+06
# Katsina                                 1.165436e+06
# Ogun                                    5.077926e+04
#
#                                  annual_avg_consum_loss_pct  \
# region
# Borno                                             17.422216
# Nasarawa                                           4.279291
# Adamawa                                            6.685643
# Taraba                                             6.930000
# Bayelsa                                            0.325052
# Benue                                              5.463897
# Plateau                                            7.334185
# Yobe                                               3.987489
# Rivers                                            -0.662135
# Abuja Federal Capital Territory                    2.266202
# Cross River                                        2.302144
# Delta                                              0.636534
# Lagos                                             -0.066867
# Abia                                              -0.714546
# Ondo                                               0.755867
# Osun                                              -0.684505
# Kogi                                               0.340910
# Kaduna                                            -0.707509
# Zamfara                                            1.254482
# Edo                                                1.273638
# Anambra                                           -0.329028
# Gombe                                              2.040122
# Enugu                                             -0.500365
# Ebonyi                                             1.247028
# Ekiti                                              3.423101
# Akwa Ibom                                         -0.423273
# Sokoto                                            -0.133471
# Bauchi                                             0.936786
# Oyo                                               -0.798205
# Jigawa                                             0.348560
# Kano                                              -0.732018
# Niger                                              0.478322
# Kwara                                              1.132187
# Imo                                               -0.365367
# Kebbi                                              0.855833
# Katsina                                            1.078133
# Ogun                                               0.686980
#
#                                  mean_recovery_rate         r  New bins
# region
# Borno                                     -0.000634 -0.062949         4
# Nasarawa                                   0.004960 -0.021488         3
# Adamawa                                    0.001467 -0.009272         3
# Taraba                                    -0.002235 -0.006680         3
# Bayelsa                                   -0.000356 -0.066798         3
# Benue                                      0.005479 -0.007952         3
# Plateau                                    0.002941 -0.047777         3
# Yobe                                      -0.000212  0.000933         2
# Rivers                                     0.000344  0.007738         2
# Abuja Federal Capital Territory           -0.020328 -0.180265         2
# Cross River                                0.000571  0.006540         2
# Delta                                     -0.001747 -0.051636         2
# Lagos                                      0.000647 -0.105710         1
# Abia                                      -0.001613 -0.016060         1
# Ondo                                      -0.002808  0.001463         1
# Osun                                       0.020983  0.001943         1
# Kogi                                      -0.000207  0.002283         1
# Kaduna                                     0.015753  0.012571         1
# Zamfara                                    0.001333  0.001001         1
# Edo                                       -0.013125 -0.034255         1
# Anambra                                   -0.000274 -0.022542         1
# Gombe                                     -0.009436  0.000789         1
# Enugu                                     -0.000021  0.000490         1
# Ebonyi                                    -0.004136  0.002107         1
# Ekiti                                     -0.018577  0.017927         1
# Akwa Ibom                                  0.000593 -0.003641         0
# Sokoto                                     0.004135  0.000808         0
# Bauchi                                    -0.006166  0.000584         0
# Oyo                                        0.011371  0.032536         0
# Jigawa                                     0.000456  0.000535         0
# Kano                                       0.004114  0.002352         0
# Niger                                     -0.002140 -0.000692         0
# Kwara                                     -0.004762 -0.007225         0
# Imo                                       -0.000173 -0.000852         0
# Kebbi                                     -0.002505  0.000324         0
# Katsina                                   -0.000360  0.000546         0
# Ogun                                      -0.007799 -0.038961         0

# %%
aggregation = 'median'
country = 'Nigeria'
conflict = get_spatial_outcomes(outcomes=conflict, country=country, aggregation=aggregation)
no_conflict = get_spatial_outcomes(outcomes=no_conflict, country=country, aggregation=aggregation)
conflict[['tot_exposed_asset', 'tot_consum_loss_npv', 'region_pml']] /= 1000000
conflict[['tot_exposed_asset', 'tot_consum_loss_npv', 'region_pml']] = conflict[['tot_exposed_asset', 'tot_consum_loss_npv', 'region_pml']].round(2)
no_conflict[['tot_exposed_asset', 'tot_consum_loss_npv', 'region_pml']] /= 1000000
no_conflict[['tot_exposed_asset', 'tot_consum_loss_npv', 'region_pml']] = no_conflict[['tot_exposed_asset', 'tot_consum_loss_npv', 'region_pml']].round(2)

# %%
conflict.columns
# Out:
# Index(['shapeName', 'shapeISO', 'shapeID', 'shapeGroup', 'shapeType',
#        'geometry', 'tot_asset_loss', 'region_pml', 'tot_exposed_asset',
#        'tot_consum_loss_npv', 'n_aff_people', 'n_new_poor',
#        'new_poverty_gap_all', 'annual_avg_consum_loss',
#        'annual_avg_consum_loss_pct', 'n_new_poor_increase_pp', 'n_poor_ratio',
#        'r'],
#       dtype='object')

# %%
k = 5
column = 'annual_avg_consum_loss_pct'
title = 'Ann. Av. Cons. Loss PC (%)'
cmap = 'YlOrRd'
scheme = 'fisher_jenks'
ax = conflict.plot(column=column, scheme=scheme, k=k, cmap=cmap, legend=True, figsize=(10,10), legend_kwds={"title":title, "loc" : "upper right"})
conflict.plot(ax=ax, color='none', edgecolor='black', linewidth=0.25)
ax.axis('off')
for idx, row in conflict.iterrows():
    ax.annotate(text=row['shapeName'], xy=row['geometry'].centroid.coords[0], ha='center', fontsize=12)
plt.savefig('consumption_loss_pct.png', dpi=300, bbox_inches='tight', transparent=True)

# %%
k = 5
column = 'annual_avg_consum_loss_pct'
title = 'Ann. Av. Cons. Loss PC (%)'
cmap = 'YlOrRd'
scheme = 'fisher_jenks'
ax = no_conflict.plot(column=column, scheme=scheme, k=k, cmap=cmap, legend=True, figsize=(10,10), legend_kwds={"title":title, "loc" : "upper right", 'fmt':'%.2f'})
no_conflict.plot(ax=ax, color='none', edgecolor='black', linewidth=0.25)
ax.axis('off')
for idx, row in conflict.iterrows():
    ax.annotate(text=row['shapeName'], xy=row['geometry'].centroid.coords[0], ha='center', fontsize=12)
plt.savefig('consumption_loss_pct.png', dpi=300, bbox_inches='tight', transparent=True)

# %%
import mapclassify as mc
# Manually classify the data with Fisher-Jenks
classifier = mc.FisherJenks(conflict['delta'], k=5)
conflict['class'] = classifier.yb
conflict['class']

# Get the values for each class
class_values = [conflict.loc[conflict['class'] == i, 'delta'].values for i in range(5)]
class_values

d = {0 : 'Not significant',
     1 : 'Not significant',
     2 : '2-5',
     3 : '5-7',
     4 : '7-18'}
conflict['class_text'] = conflict['class'].map(d)
# Make class text to categorical
conflict['class_text'] = pd.Categorical(conflict['class_text'], categories=['Not significant', '2-5', '5-7', '7-18'], ordered=True)

# %%
delta = no_conflict['annual_avg_consum_loss_pct'] - conflict['annual_avg_consum_loss_pct']
conflict['delta'] = delta.round()
k = 5
column = 'class_text'
title = 'Diff. Ann. Av. Cons. Loss PC (%)'
cmap = 'YlOrRd'
scheme = 'fisher_jenks'
ax = conflict.plot(column=column, categorical=True, cmap=cmap, legend=True, figsize=(8,8), legend_kwds={"title":title, "loc" : "lower right", 'fmt': '{:.0f}'})
conflict.plot(ax=ax, color='none', edgecolor='black', linewidth=0.25)
ax.axis('off')
for idx, row in conflict.iterrows():
    ax.annotate(text=row['shapeName'], xy=row['geometry'].centroid.coords[0], ha='center', fontsize=12)
plt.title('Difference in Consumption Loss (%) between No Conflict and Conflict', fontsize=14)
plt.savefig('delta_consumption_loss_pct.png', dpi=300, bbox_inches='tight', transparent=True)

# %% [markdown]
# ### Single scenario, single district

# %%
# Print all outcomes for a single scenario
scenario = 0
df = outcomes[outcomes['scenario'] == scenario].copy()
df.set_index('region', inplace=True)
# df.drop(columns=['weighted_vuln_quint', 'weighted_vuln_dec'], inplace=True)
numeric_columns = df.columns[3:-1].tolist()
df[numeric_columns].round(2).style.format("{:,.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_bff69">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bff69_level0_col0" class="col_heading level0 col0" >tot_pop</th>
#       <th id="T_bff69_level0_col1" class="col_heading level0 col1" >n_aff_people</th>
#       <th id="T_bff69_level0_col2" class="col_heading level0 col2" >n_retrofitted</th>
#       <th id="T_bff69_level0_col3" class="col_heading level0 col3" >n_retrofitted_hh</th>
#       <th id="T_bff69_level0_col4" class="col_heading level0 col4" >n_aff_retrofitted</th>
#       <th id="T_bff69_level0_col5" class="col_heading level0 col5" >n_aff_retrofitted_hh</th>
#       <th id="T_bff69_level0_col6" class="col_heading level0 col6" >tot_asset_surv</th>
#       <th id="T_bff69_level0_col7" class="col_heading level0 col7" >tot_exposed_asset</th>
#       <th id="T_bff69_level0_col8" class="col_heading level0 col8" >tot_asset_loss</th>
#       <th id="T_bff69_level0_col9" class="col_heading level0 col9" >expected_loss_frac</th>
#       <th id="T_bff69_level0_col10" class="col_heading level0 col10" >region_pml</th>
#       <th id="T_bff69_level0_col11" class="col_heading level0 col11" >annual_avg_consum</th>
#       <th id="T_bff69_level0_col12" class="col_heading level0 col12" >pov_line_adjust</th>
#       <th id="T_bff69_level0_col13" class="col_heading level0 col13" >mean_recovery_rate</th>
#       <th id="T_bff69_level0_col14" class="col_heading level0 col14" >tot_consum_loss_npv</th>
#       <th id="T_bff69_level0_col15" class="col_heading level0 col15" >n_poor_initial</th>
#       <th id="T_bff69_level0_col16" class="col_heading level0 col16" >n_poor_affected</th>
#       <th id="T_bff69_level0_col17" class="col_heading level0 col17" >n_new_poor</th>
#       <th id="T_bff69_level0_col18" class="col_heading level0 col18" >initial_poverty_gap</th>
#       <th id="T_bff69_level0_col19" class="col_heading level0 col19" >new_poverty_gap_initial</th>
#       <th id="T_bff69_level0_col20" class="col_heading level0 col20" >new_poverty_gap_all</th>
#       <th id="T_bff69_level0_col21" class="col_heading level0 col21" >annual_avg_consum_loss</th>
#       <th id="T_bff69_level0_col22" class="col_heading level0 col22" >annual_avg_consum_loss_pct</th>
#       <th id="T_bff69_level0_col23" class="col_heading level0 col23" >r</th>
#       <th id="T_bff69_level0_col24" class="col_heading level0 col24" >n_poor_ratio</th>
#       <th id="T_bff69_level0_col25" class="col_heading level0 col25" >n_new_poor_increase_pp</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >region</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#       <th class="blank col24" >&nbsp;</th>
#       <th class="blank col25" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bff69_level0_row0" class="row_heading level0 row0" >St. George</th>
#       <td id="T_bff69_row0_col0" class="data row0 col0" >90,278.69</td>
#       <td id="T_bff69_row0_col1" class="data row0 col1" >52,250.89</td>
#       <td id="T_bff69_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_bff69_row0_col3" class="data row0 col3" >0.00</td>
#       <td id="T_bff69_row0_col4" class="data row0 col4" >0.00</td>
#       <td id="T_bff69_row0_col5" class="data row0 col5" >0.00</td>
#       <td id="T_bff69_row0_col6" class="data row0 col6" >5,398,394,680.58</td>
#       <td id="T_bff69_row0_col7" class="data row0 col7" >1,002,936,475.89</td>
#       <td id="T_bff69_row0_col8" class="data row0 col8" >193,411,510.27</td>
#       <td id="T_bff69_row0_col9" class="data row0 col9" >0.20</td>
#       <td id="T_bff69_row0_col10" class="data row0 col10" >195,870,372.33</td>
#       <td id="T_bff69_row0_col11" class="data row0 col11" >2,490.49</td>
#       <td id="T_bff69_row0_col12" class="data row0 col12" >1,157.44</td>
#       <td id="T_bff69_row0_col13" class="data row0 col13" >0.30</td>
#       <td id="T_bff69_row0_col14" class="data row0 col14" >151,639,599.03</td>
#       <td id="T_bff69_row0_col15" class="data row0 col15" >13,861.00</td>
#       <td id="T_bff69_row0_col16" class="data row0 col16" >7,690.00</td>
#       <td id="T_bff69_row0_col17" class="data row0 col17" >7,042.00</td>
#       <td id="T_bff69_row0_col18" class="data row0 col18" >19.96</td>
#       <td id="T_bff69_row0_col19" class="data row0 col19" >24.44</td>
#       <td id="T_bff69_row0_col20" class="data row0 col20" >20.22</td>
#       <td id="T_bff69_row0_col21" class="data row0 col21" >290.21</td>
#       <td id="T_bff69_row0_col22" class="data row0 col22" >11.47</td>
#       <td id="T_bff69_row0_col23" class="data row0 col23" >3.12</td>
#       <td id="T_bff69_row0_col24" class="data row0 col24" >15.00</td>
#       <td id="T_bff69_row0_col25" class="data row0 col25" >7.80</td>
#     </tr>
#     <tr>
#       <th id="T_bff69_level0_row1" class="row_heading level0 row1" >St. John</th>
#       <td id="T_bff69_row1_col0" class="data row1 col0" >18,973.86</td>
#       <td id="T_bff69_row1_col1" class="data row1 col1" >10,893.58</td>
#       <td id="T_bff69_row1_col2" class="data row1 col2" >0.00</td>
#       <td id="T_bff69_row1_col3" class="data row1 col3" >0.00</td>
#       <td id="T_bff69_row1_col4" class="data row1 col4" >0.00</td>
#       <td id="T_bff69_row1_col5" class="data row1 col5" >0.00</td>
#       <td id="T_bff69_row1_col6" class="data row1 col6" >1,525,653,735.63</td>
#       <td id="T_bff69_row1_col7" class="data row1 col7" >146,917,090.94</td>
#       <td id="T_bff69_row1_col8" class="data row1 col8" >31,077,920.12</td>
#       <td id="T_bff69_row1_col9" class="data row1 col9" >0.21</td>
#       <td id="T_bff69_row1_col10" class="data row1 col10" >30,721,128.56</td>
#       <td id="T_bff69_row1_col11" class="data row1 col11" >1,325.95</td>
#       <td id="T_bff69_row1_col12" class="data row1 col12" >599.94</td>
#       <td id="T_bff69_row1_col13" class="data row1 col13" >0.27</td>
#       <td id="T_bff69_row1_col14" class="data row1 col14" >21,224,802.52</td>
#       <td id="T_bff69_row1_col15" class="data row1 col15" >3,569.00</td>
#       <td id="T_bff69_row1_col16" class="data row1 col16" >2,059.00</td>
#       <td id="T_bff69_row1_col17" class="data row1 col17" >557.00</td>
#       <td id="T_bff69_row1_col18" class="data row1 col18" >15.89</td>
#       <td id="T_bff69_row1_col19" class="data row1 col19" >22.49</td>
#       <td id="T_bff69_row1_col20" class="data row1 col20" >21.05</td>
#       <td id="T_bff69_row1_col21" class="data row1 col21" >194.84</td>
#       <td id="T_bff69_row1_col22" class="data row1 col22" >15.38</td>
#       <td id="T_bff69_row1_col23" class="data row1 col23" >1.27</td>
#       <td id="T_bff69_row1_col24" class="data row1 col24" >19.00</td>
#       <td id="T_bff69_row1_col25" class="data row1 col25" >2.94</td>
#     </tr>
#     <tr>
#       <th id="T_bff69_level0_row2" class="row_heading level0 row2" >St. Peter</th>
#       <td id="T_bff69_row2_col0" class="data row2 col0" >5,125.54</td>
#       <td id="T_bff69_row2_col1" class="data row2 col1" >3,601.90</td>
#       <td id="T_bff69_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_bff69_row2_col3" class="data row2 col3" >0.00</td>
#       <td id="T_

# %%
# Let's examine a single scenario in details
scenario = 0
df = outcomes[outcomes['scenario'] == scenario].copy()
df.set_index('region', inplace=True)

# And a single district as an example
district = 'St. George'
print('District: ', district)
total_population = round(df.loc[district, 'tot_pop'])
n_affected = round(df.loc[district, 'n_aff_people'])
print('Total population: ', total_population)
print('Number of affected people: ', n_affected)

n_poor_initial = round(df.loc[district, 'n_poor_initial'])
n_new_poor = round(df.loc[district, 'n_new_poor'])
pct_poor_initial = round(n_poor_initial / total_population * 100, 2)
pct_new_poor = round((n_new_poor + n_poor_initial) / total_population * 100, 2)
pct_poor_increase = round(n_new_poor / total_population * 100, 2)
initial_poverty_gap = round(df.loc[district, 'initial_poverty_gap'], 2)
new_poverty_gap_init = round(df.loc[district, 'new_poverty_gap_initial'], 2)
new_poverty_gap_all = round(df.loc[district, 'new_poverty_gap_all'], 2)
print()
print('Number of poor: ', n_poor_initial)
print('Number of new poor: ', n_new_poor)
print(f'Percentage of poor: {pct_poor_initial}%')
print(f'Percentage of new poor: {pct_new_poor}%')
print(f'Percentage of increase in poor: {pct_poor_increase}%')
print('Initial poverty gap: ', initial_poverty_gap)
print('New poverty gap initial poor: ', new_poverty_gap_init)
print('New poverty gap all poor: ', new_poverty_gap_all)

annual_average_consumption = round(df.loc[district, 'annual_avg_consum'])
annual_average_consumption_loss = round(df.loc[district, 'annual_avg_consum_loss'])
annual_average_consumption_loss_pct = round(df.loc[district, 'annual_avg_consum_loss_pct'])
print()

print('Annual average consumption: ', annual_average_consumption)
print('Annual average consumption loss: ', annual_average_consumption_loss)
print(f'Annual average consumption loss percentage: {annual_average_consumption_loss_pct}%')

print()
r = round(df.loc[district, 'r'], 2)
print('Socio-economic resilience: ', r)
# Out:
# District:  St. George
# Total population:  90279
# Number of affected people:  52251
#
# Number of poor:  13861
# Number of new poor:  7042
# Percentage of poor: 15.35%
# Percentage of new poor: 23.15%
# Percentage of increase in poor: 7.8%
# Initial poverty gap:  19.96
# New poverty gap initial poor:  24.44
# New poverty gap all poor:  20.22
#
# Annual average consumption:  2490
# Annual average consumption loss:  290
# Annual average consumption loss percentage: 11%
#
# Socio-economic resilience:  3.12

# %%
annotated_hist(outcomes, savefig=savefig, annotate=False)
plt.savefig(figures_folder + 'consumption_loss_hist.png', dpi=300, bbox_inches='tight')

# %%
# # Print all outcomes for a single scenario
# district = 'St. George'
# df = outcomes[outcomes['district'] == district].copy()
# df.drop(columns=['years_in_poverty'], inplace=True)
# columns_of_interest = ['total_consumption_loss', 
#                        'n_affected_people', 'annual_average_consumption', 'n_new_poor', 'n_poor_affected',
#                        'annual_average_consumption_loss', 'annual_average_consumption_loss_pct', 'r', 'n_new_poor_increase_pp']
# sns.pairplot(df[columns_of_interest])
# plt.tight_layout();

# %% [markdown]
# ### Multiple scenarios & multiple districts

# %%
# Let's aggregate across scenarios and take the mean
df = outcomes.iloc[:, 2:-1].groupby('region').mean(numeric_only=True).round(2)
df['fraction_affected'] = df['n_aff_people'] / df['tot_pop']
df['fraction_affected'].sort_values(ascending=False)
# Out:
# region
# St. Paul       0.772875
# St. Luke       0.742490
# St. Peter      0.716857
# St. Patrick    0.683970
# St. Joseph     0.677432
# St. Andrew     0.597007
# St. David      0.589510
# St. George     0.588486
# St. John       0.569239
# St. Mark       0.528666
# Name: fraction_affected, dtype: float64

# %%
# Let's aggregate across scenarios and take the mean
outcomes.iloc[:, 2:-1].groupby('region').mean(numeric_only=True).round(2).sort_values(by='r', ascending=False)
# Out:
#               random_seed   tot_pop  n_aff_people  n_retrofitted  \
# region
# St. Peter    5.000018e+08   5125.54       3674.28            0.0
# St. Mark     5.000018e+08  11992.24       6339.89            0.0
# St. George   5.000018e+08  90278.69      53127.71            0.0
# St. Paul     5.000018e+08  35699.75      27591.46            0.0
# St. John     5.000018e+08  18973.86      10800.67            0.0
# St. Luke     5.000018e+08   7241.94       5377.07            0.0
# St. David    5.000018e+08  26585.01      15672.12            0.0
# St. Patrick  5.000018e+08  36798.71      25169.23            0.0
# St. Andrew   5.000018e+08  46678.50      27867.39            0.0
# St. Joseph   5.000018e+08  28970.38      19625.45            0.0
#
#              n_retrofitted_hh  n_aff_retrofitted  n_aff_retrofitted_hh  \
# region
# St. Peter                 0.0                0.0                   0.0
# St. Mark                  0.0                0.0                   0.0
# St. George                0.0                0.0                   0.0
# St. Paul                  0.0                0.0                   0.0
# St. John                  0.0                0.0                   0.0
# St. Luke                  0.0                0.0                   0.0
# St. David                 0.0                0.0                   0.0
# St. Patrick               0.0                0.0                   0.0
# St. Andrew                0.0                0.0                   0.0
# St. Joseph                0.0                0.0                   0.0
#
#              tot_asset_surv  tot_exposed_asset  tot_asset_loss  ...  \
# region                                                          ...
# St. Peter      2.254011e+08       8.191400e+07    1.896813e+07  ...
# St. Mark       5.378013e+08       1.252735e+08    2.347021e+07  ...
# St. George     5.391320e+09       1.002936e+09    1.958653e+08  ...
# St. Paul       1.881712e+09       3.820905e+08    9.983306e+07  ...
# St. John       1.536831e+09       1.469171e+08    3.069823e+07  ...
# St. Luke       4.074323e+08       4.170058e+07    1.108052e+07  ...
# St. David      1.902591e+09       1.148812e+08    2.539705e+07  ...
# St. Patrick    1.636505e+09       1.492033e+08    3.681943e+07  ...
# St. Andrew     2.424014e+09       2.191651e+08    4.917455e+07  ...
# St. Joseph     1.768665e+09       1.752688e+08    4.268454e+07  ...
#
#              n_poor_affected  n_new_poor  initial_poverty_gap  \
# region
# St. Peter             831.89       86.29                24.22
# St. Mark             1951.29      277.93                12.65
# St. George           8161.76     7215.07                19.96
# St. Paul            11546.23     1212.91                37.64
# St. John             2033.76      533.36                15.89
# St. Luke              956.86      502.20                50.19
# St. David            7390.41      545.20                30.03
# St. Patrick         12064.93     1078.98                36.71
# St. Andrew          13605.08     2981.84                41.82
# St. Joseph          10436.13       98.53                33.22
#
#              new_poverty_gap_initial  new_poverty_gap_all  \
# region
# St. Peter                      29.03                27.36
# St. Mark                       17.25                16.84
# St. George                     25.23                21.06
# St. Paul                       44.91                42.18
# St. John                       23.00                21.48
# St. Luke                       54.71                43.77
# St. David                      35.83                34.77
# St. Patrick                    42.87                40.51
# St. Andrew                     47.85                43.54
# St. Joseph                     41.83                41.67
#
#              annual_avg_consum_loss  annual_avg_consum_loss_pct     r  \
# region
# St. Peter                    427.42                       11.68  5.78
# St. Mark                     292.85                       10.60  4.02
# St. George                   285.85                       11.57  3.07
# St. Paul                     280.91                       12.86  2.22
# St. John                     194.04                       15.49  1.26
# St. Luke                     148.10                       14.15  0.90
# St. David                     99.57                       12.97  0.59
# St. Patrick                  101.48                       14.35  0.53
# St. Andrew                   118.99                       16.47  0.52
# St. Joseph                   152.49                       19.35  0.51
#
#              n_poor_ratio  n_new_poor_increase_pp
# region
# St. Peter            23.0                    1.68
# St. Mark             31.0                    2.32
# St. George           15.0                    7.99
# St. Paul             42.0                    3.40
# St. John             19.0                    2.81
# St. Luke             18.0                    6.93
# St. David            47.0                    2.05
# St. Patrick          48.0                    2.93
# St. Andrew           49.0                    6.39
# St. Joseph           53.0                    0.34
#
# [10 rows x 27 columns]

# %%
coloured_density_plots(outcomes, savefig, scheme='fisher_jenks', k=4)
plt.savefig(figures_folder + 'consumption_loss_density.png', dpi=300, bbox_inches='tight')

# %%
tab = outcomes.iloc[:, 2:-1].groupby('region').describe().round(2)
column = 'n_new_poor'
tab = tab.sort_values(by=(column, 'mean'), ascending=False)
tab[[column]].iloc[:,1:].style.format("{:,.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_91911">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_91911_level0_col0" class="col_heading level0 col0" colspan="7">n_new_poor</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_91911_level1_col0" class="col_heading level1 col0" >mean</th>
#       <th id="T_91911_level1_col1" class="col_heading level1 col1" >std</th>
#       <th id="T_91911_level1_col2" class="col_heading level1 col2" >min</th>
#       <th id="T_91911_level1_col3" class="col_heading level1 col3" >25%</th>
#       <th id="T_91911_level1_col4" class="col_heading level1 col4" >50%</th>
#       <th id="T_91911_level1_col5" class="col_heading level1 col5" >75%</th>
#       <th id="T_91911_level1_col6" class="col_heading level1 col6" >max</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >region</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91911_level0_row0" class="row_heading level0 row0" >St. George</th>
#       <td id="T_91911_row0_col0" class="data row0 col0" >7,215.07</td>
#       <td id="T_91911_row0_col1" class="data row0 col1" >861.88</td>
#       <td id="T_91911_row0_col2" class="data row0 col2" >3,527.00</td>
#       <td id="T_91911_row0_col3" class="data row0 col3" >6,636.00</td>
#       <td id="T_91911_row0_col4" class="data row0 col4" >7,204.00</td>
#       <td id="T_91911_row0_col5" class="data row0 col5" >7,799.00</td>
#       <td id="T_91911_row0_col6" class="data row0 col6" >10,611.00</td>
#     </tr>
#     <tr>
#       <th id="T_91911_level0_row1" class="row_heading level0 row1" >St. Andrew</th>
#       <td id="T_91911_row1_col0" class="data row1 col0" >2,981.84</td>
#       <td id="T_91911_row1_col1" class="data row1 col1" >273.27</td>
#       <td id="T_91911_row1_col2" class="data row1 col2" >1,925.00</td>
#       <td id="T_91911_row1_col3" class="data row1 col3" >2,804.00</td>
#       <td id="T_91911_row1_col4" class="data row1 col4" >2,990.50</td>
#       <td id="T_91911_row1_col5" class="data row1 col5" >3,166.25</td>
#       <td id="T_91911_row1_col6" class="data row1 col6" >3,802.00</td>
#     </tr>
#     <tr>
#       <th id="T_91911_level0_row2" class="row_heading level0 row2" >St. Paul</th>
#       <td id="T_91911_row2_col0" class="data row2 col0" >1,212.91</td>
#       <td id="T_91911_row2_col1" class="data row2 col1" >511.98</td>
#       <td id="T_91911_row2_col2" class="data row2 col2" >631.00</td>
#       <td id="T_91911_row2_col3" class="data row2 col3" >828.00</td>
#       <td id="T_91911_row2_col4" class="data row2 col4" >888.00</td>
#       <td id="T_91911_row2_col5" class="data row2 col5" >1,717.00</td>
#       <td id="T_91911_row2_col6" class="data row2 col6" >2,975.00</td>
#     </tr>
#     <tr>
#       <th id="T_91911_level0_row3" class="row_heading level0 row3" >St. Patrick</th>
#       <td id="T_91911_row3_col0" class="data row3 col0" >1,078.98</td>
#       <td id="T_91911_row3_col1" class="data row3 col1" >722.43</td>
#       <td id="T_91911_row3_col2" class="data row3 col2" >31.00</td>
#       <td id="T_91911_row3_col3" class="data row3 col3" >172.00</td>
#       <td id="T_91911_row3_col4" class="data row3 col4" >1,405.50</td>
#       <td id="T_91911_row3_col5" class="data row3 col5" >1,663.00</td>
#       <td id="T_91911_row3_col6" class="data row3 col6" >2,364.00</td>
#     </tr>
#     <tr>
#       <th id="T_91911_level0_row4" class="row_heading level0 row4" >St. David</th>
#       <td id="T_91911_row4_col0" class="data row4 col0" >545.20</td>
#       <td id="T_91911_row4_col1" class="data row4 col1" >73.58</td>
#       <td id="T_91911_row4_col2" class="data row4 col2" >274.00</td>
#       <td id="T_91911_row4_col3" class="data row4 col3" >496.00</td>
#       <td id="T_91911_row4_col4" class="data row4 col4" >545.00</td>
#       <td id="T_91911_row4_col5" class="data row4 col5" >594.00</td>
#       <td id="T_91911_row4_col6" class="data row4 col6" >811.00</td>
#     </tr>
#     <tr>
#       <th id="T_91911_level0_row5" class="row_heading level0 row5" >St. John</th>
#       <td id="T_91911_row5_col0" class="data row5 col0" >533.36</td>
#       <td id="T_91911_row5_col1" class="data row5 col1" >50.03</td>
#       <td id="T_91911_row5_col2" class="data row5 col2" >372.00</td>
#       <td id="T_91911_row5_col3" class="data row5 col3" >500.00</td>
#       <td id="T_91911_row5_col4" class="data row5 col4" >533.00</td>
#       <td id="T_91911_row5_col5" class="data row5 col5" >567.00</td>
#       <td id="T_91911_row5_col6" class="data row5 col6" >709.00</td>
#     </tr>
#     <tr>
#       <th id="T_91911_level0_row6" class="row_heading level0 row6" >St. Luke</th>
#       <td id="T_91911_row6_col0" class="data row6 col0" >502.20</td>
#       <td id="T_91911_row6_col1" class="data row6 col1" >35.72</td>
#       <td id="T_91911_row6_col2" class="data row6 col2" >396.00</td>
#       <td id="T_91911_row6_col3" class="data row6 col3" >479.00</td>
#       <td id="T_91911_row6_col4" class="data row6 col4" >503.00</td>
#       <td id="T_91911_row6_col5" class="data row6 col5" >527.00</td>
#       <td id="T_91911_row6_col6" class="data row6 col6" >629.00</td>
#     </tr>
#     <tr>
#       <th id="T_91911_level0_row7" class="row_heading level0 row7" >St. Mark</th>
#       <td id="T_91911_row7_col0" class="data row7 col0" >277.93</td>
#       <td id="T_91911_row7_col1" class="data row7 col1" >34.71</td>
#       <td id="T_91911_row7_col2" class="data row7 col2" >140.00</td>
#       <td id="T_91911_row7_col3" class="data row7 col3" >254.00</td>
#       <td id="T_91911_row7_col4" class="data row7 col4" >277.00</td>
#       <td id="T_91911_row7_col5" class="data row7 col5" >302.00</td>
#       <td id="T_91911_row7_col6" class="data row7 col6" >393.00</td>
#     </tr>
#     <tr>
#       <th id="T_91911_level0_row8" class="row_heading level0 row8" >St. Joseph</th>
#       <td id="T_91911_row8_col0" class="data row8 col0" >98.53</td>
#       <td id="T_91911_row8_col1" class="data row8 col1" >8.38</td>
#       <td id="T_91911_row8_col2" class="data row8 col2" >65.00</td>
#       <td id="T_91911_row8_col3" class="data row8 col3" >93.00</td>
#       <td id="T_91911_row8_col4" class="data row8 col4" >99.00</td>
#       <td id="T_91911_row8_col5" class="data row8 col5" >104.00</td>
#       <td id="T_91911_row8_col6" class="data row8 col6" >127.00</td>
#     </tr>
#     <tr>
#       <th id="T_91911_level0_row9" class="row_heading level0 row9" >St. Peter</th>
#       <td id="T_91911_row9_col0" class="data row9 col0" >86.29</td>
#       <td id="T_91911_row9_col1" class="data row9 col1" >85.37</td>
#       <td id="T_91911_row9_col2" class="data row9 col2" >18.00</td>
#       <td id="T_91911_row9_col3" class="data row9 col3" >22.00</td>
#       <td id="T_91911_row9_col4" class="data row9 col4" >23.00</td>
#       <td id="T_91911_row9_col5" class="data row9 col5" >191.00</td>
#       <td id="T_91911_row9_col6" class="data row9 col6" >241.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Weeks in poverty & Number of new poor

# %%
average_years_in_poverty = {}
for district in outcomes['region'].unique():
    df = outcomes[outcomes['region'] == district].copy()
    total_years_in_poverty = {}
    for d in df['years_in_poverty']:
        for key, value in d.items():
            total_years_in_poverty[key] = total_years_in_poverty.get(key, 0) + value
    average_years_in_poverty[district] = {k: v / len(df) for k, v in total_years_in_poverty.items()}
average_years_in_poverty = pd.DataFrame(average_years_in_poverty).T

# %%
average_years_in_poverty = get_weeks_in_poverty_tab(outcomes)

if savetab:
    # average_years_in_poverty.rename({'Anse-La-Raye & Canaries': 'Anse-La-Raye \& Canaries'}, inplace=True, axis=0)
    average_years_in_poverty.astype(int).style\
        .background_gradient(cmap='Blues', axis=0)\
        .set_caption('Average Years in Poverty By District')\
        .to_latex(tables_folder + 'av_years_in_pov.tex',
                  # escape=False,
                  caption='Average Years in Poverty By District',
                  label='tab:av_years_in_pov',
                  convert_css=True,
                  multicol_align="|c|",
                  hrules=True,
                  position_float="centering")

# %%
# Number of people in poverty for 1 / 3 / 5 years

# %%
# More than 1 year in poverty
n_years = 1
average_years_in_poverty.iloc[:,n_years:].sum(axis=1)
# Out:
# Region
# St. George     7215.088333
# St. John        533.384667
# St. Peter        86.266667
# St. Joseph       98.566000
# St. Paul       1212.926333
# St. Luke        502.186667
# St. Mark        277.900667
# St. Patrick    1078.984667
# St. David       545.215667
# St. Andrew     2981.810667
# dtype: float64

# %%
# More than 3 years in poverty
n_years = 3
average_years_in_poverty.iloc[:,n_years:].sum(axis=1)
# Out:
# Region
# St. George     7212.806667
# St. John        533.384667
# St. Peter        86.266667
# St. Joseph       98.566000
# St. Paul       1203.551333
# St. Luke        502.186667
# St. Mark        277.729667
# St. Patrick     833.908667
# St. David       545.215667
# St. Andrew     2981.395667
# dtype: float64

# %%
# More than 5 years in poverty
n_years = 5
average_years_in_poverty.iloc[:,n_years:].sum(axis=1)
# Out:
# Region
# St. George     4775.538000
# St. John        358.411000
# St. Peter        10.355333
# St. Joseph       76.631000
# St. Paul        502.514333
# St. Luke        481.040333
# St. Mark        262.089000
# St. Patrick      20.130333
# St. David        21.540000
# St. Andrew     1227.643000
# dtype: float64

# %%
average_years_in_poverty.astype(int).style\
        .background_gradient(cmap='Blues', axis=0)\
        .set_caption('Average Years in Poverty By District')
# Out:
# <style type="text/css">
# #T_1f3b3_row0_col0, #T_1f3b3_row0_col1, #T_1f3b3_row0_col8, #T_1f3b3_row0_col9, #T_1f3b3_row0_col10, #T_1f3b3_row1_col0, #T_1f3b3_row1_col1, #T_1f3b3_row1_col2, #T_1f3b3_row1_col4, #T_1f3b3_row1_col7, #T_1f3b3_row1_col8, #T_1f3b3_row1_col9, #T_1f3b3_row1_col10, #T_1f3b3_row2_col0, #T_1f3b3_row2_col1, #T_1f3b3_row2_col2, #T_1f3b3_row2_col4, #T_1f3b3_row2_col5, #T_1f3b3_row2_col6, #T_1f3b3_row2_col7, #T_1f3b3_row2_col8, #T_1f3b3_row2_col9, #T_1f3b3_row2_col10, #T_1f3b3_row3_col0, #T_1f3b3_row3_col1, #T_1f3b3_row3_col2, #T_1f3b3_row3_col3, #T_1f3b3_row3_col5, #T_1f3b3_row3_col8, #T_1f3b3_row3_col9, #T_1f3b3_row3_col10, #T_1f3b3_row4_col0, #T_1f3b3_row4_col1, #T_1f3b3_row4_col8, #T_1f3b3_row4_col9, #T_1f3b3_row4_col10, #T_1f3b3_row5_col0, #T_1f3b3_row5_col1, #T_1f3b3_row5_col2, #T_1f3b3_row5_col3, #T_1f3b3_row5_col8, #T_1f3b3_row5_col9, #T_1f3b3_row5_col10, #T_1f3b3_row6_col0, #T_1f3b3_row6_col1, #T_1f3b3_row6_col2, #T_1f3b3_row6_col4, #T_1f3b3_row6_col6, #T_1f3b3_row6_col7, #T_1f3b3_row6_col8, #T_1f3b3_row6_col9, #T_1f3b3_row6_col10, #T_1f3b3_row7_col0, #T_1f3b3_row7_col1, #T_1f3b3_row7_col4, #T_1f3b3_row7_col6, #T_1f3b3_row7_col7, #T_1f3b3_row7_col8, #T_1f3b3_row7_col9, #T_1f3b3_row7_col10, #T_1f3b3_row8_col0, #T_1f3b3_row8_col1, #T_1f3b3_row8_col2, #T_1f3b3_row8_col3, #T_1f3b3_row8_col6, #T_1f3b3_row8_col7, #T_1f3b3_row8_col8, #T_1f3b3_row8_col9, #T_1f3b3_row8_col10, #T_1f3b3_row9_col0, #T_1f3b3_row9_col1, #T_1f3b3_row9_col2, #T_1f3b3_row9_col8, #T_1f3b3_row9_col9, #T_1f3b3_row9_col10 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_1f3b3_row0_col2, #T_1f3b3_row1_col6 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_1f3b3_row0_col3 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_1f3b3_row0_col4, #T_1f3b3_row0_col5, #T_1f3b3_row0_col6, #T_1f3b3_row7_col2, #T_1f3b3_row9_col3, #T_1f3b3_row9_col7 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_1f3b3_row0_col7 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_1f3b3_row1_col3 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_1f3b3_row1_col5 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_1f3b3_row2_col3 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_1f3b3_row3_col4, #T_1f3b3_row3_col6, #T_1f3b3_row5_col4, #T_1f3b3_row6_col3, #T_1f3b3_row7_col5, #T_1f3b3_row8_col5 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_1f3b3_row3_col7 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_1f3b3_row4_col2, #T_1f3b3_row4_col4 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_1f3b3_row4_col3 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_1f3b3_row4_col5 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_1f3b3_row4_col6 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_1f3b3_row4_col7 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_1f3b3_row5_col5 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_1f3b3_row5_col6, #T_1f3b3_row9_col6 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_1f3b3_row5_col7 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_1f3b3_row6_col5 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_1f3b3_row7_col3 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_1f3b3_row8_col4 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_1f3b3_row9_col4 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_1f3b3_row9_col5 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# </style>
# <table id="T_1f3b3">
#   <caption>Average Years in Poverty By District</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f3b3_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_1f3b3_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_1f3b3_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_1f3b3_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_1f3b3_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_1f3b3_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_1f3b3_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_1f3b3_level0_col7" class="col_heading level0 col7" >7</th>
#       <th id="T_1f3b3_level0_col8" class="col_heading level0 col8" >8</th>
#       <th id="T_1f3b3_level0_col9" class="col_heading level0 col9" >9</th>
#       <th id="T_1f3b3_level0_col10" class="col_heading level0 col10" >10</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Region</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f3b3_level0_row0" class="row_heading level0 row0" >St. George</th>
#       <td id="T_1f3b3_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_1f3b3_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_1f3b3_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_1f3b3_row0_col3" class="data row0 col3" >644</td>
#       <td id="T_1f3b3_row0_col4" class="data row0 col4" >1792</td>
#       <td id="T_1f3b3_row0_col5" class="data row0 col5" >1969</td>
#       <td id="T_1f3b3_row0_col6" class="data row0 col6" >2189</td>
#       <td id="T_1f3b3_row0_col7" class="data row0 col7" >616</td>
#       <td id="T_1f3b3_row0_col8" class="data row0 col8" >0</td>
#       <td id="T_1f3b3_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_1f3b3_row0_col10" class="data row0 col10" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1f3b3_level0_row1" class="row_heading level0 row1" >St. John</th>
#       <td id="T_1f3b3_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_1f3b3_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_1f3b3_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_1f3b3_row1_col3" class="data row1 col3" >160</td>
#       <td id="T_1f3b3_row1_col4" class="data row1 col4" >14</td>
#       <td id="T_1f3b3_row1_col5" class="data row1 col5" >333</td>
#       <td id="T_1f3b3_row1_col6" class="data row1 col6" >24</td>
#       <td id="T_1f3b3_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_1f3b3_row1_col8" class="data row1 col8" >0</td>
#       <td id="T_1f3b3_row1_col9" class="data row1 col9" >0</td>
#       <td id="T_1f3b3_row1_col10" class="data row1 col10" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1f3b3_level0_row2" class="row_heading level0 row2" >St. Peter</th>
#       <td id="T_1f3b3_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_1f3b3_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_1f3b3_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_1f3b3_row2_col3" class="data row2 col3" >64</td>
#       <td id="T_1f3b3_row2_col4" class="data row2 col4" >11</td>
#       <td id="T_1f3b3_row2_col5" class="data row2 col5" >10</td>
#       <td id="T_1f3b3_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_1f3b3_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_1f3b3_row2_col8" class="data row2 col8" >0</td>
#       <td id="T_1f3b3_row2_col9" class="data row2 col9" >0</td>
#       <td id="T_1f3b3_row2_col10" class="data row2 col10" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1f3b3_level0_row3" class="row_heading level0 row3" >St. Joseph</th>
#       <td id="T_1f3b3_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_1f3b3_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_1f3b3_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_1f3b3_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_1f3b3_row3_col4" class="data row3 col4" >21</td>
#       <td id="T_1f3b3_row3_col5" class="data row3 col5" >10</td>
#       <td id="T_1f3b3_row3_col6" class="data row3 col6" >11</td>
#       <td id="T_1f3b3_row3_col7" class="data row3 col7" >54</td>
#       <td id="T_1f3b

# %%
# Get the number of new poor in each district
regions = outcomes['region'].unique().tolist()
n_districts = len(regions)
d = {}
for region in regions:
    df = outcomes[outcomes['region'] == region]
    d[region] = df['n_new_poor'].values.tolist()

# %%
# Make a coloured table
tab = pd.DataFrame(d).describe().T.sort_values('mean', ascending=False).round(2).drop('count', axis=1)
tab.style.background_gradient(cmap='Blues', subset=['mean'])\
         .background_gradient(cmap='Reds', subset=['std'])\
         .background_gradient(cmap='Oranges', subset=['min'])\
         .background_gradient(cmap='Greens', subset=['25%'])\
         .background_gradient(cmap='Greens', subset=['50%'])\
         .background_gradient(cmap='Greens', subset=['75%'])\
         .background_gradient(cmap='Purples', subset=['max'])\
         .format(decimal='.', thousands=',', precision=0)
# Out:
# <style type="text/css">
# #T_f05fa_row0_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_f05fa_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_f05fa_row0_col2 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_f05fa_row0_col3, #T_f05fa_row0_col4, #T_f05fa_row0_col5 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_f05fa_row0_col6 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_f05fa_row1_col0 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_f05fa_row1_col1 {
#   background-color: #fca78b;
#   color: #000000;
# }
# #T_f05fa_row1_col2 {
#   background-color: #f9802d;
#   color: #f1f1f1;
# }
# #T_f05fa_row1_col3 {
#   background-color: #91d28e;
#   color: #000000;
# }
# #T_f05fa_row1_col4 {
#   background-color: #94d390;
#   color: #000000;
# }
# #T_f05fa_row1_col5 {
#   background-color: #99d595;
#   color: #000000;
# }
# #T_f05fa_row1_col6 {
#   background-color: #c2c3df;
#   color: #000000;
# }
# #T_f05fa_row2_col0 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_f05fa_row2_col1 {
#   background-color: #f24734;
#   color: #f1f1f1;
# }
# #T_f05fa_row2_col2 {
#   background-color: #fedebd;
#   color: #000000;
# }
# #T_f05fa_row2_col3 {
#   background-color: #e5f5e1;
#   color: #000000;
# }
# #T_f05fa_row2_col4 {
#   background-color: #e6f5e1;
#   color: #000000;
# }
# #T_f05fa_row2_col5 {
#   background-color: #d1edcb;
#   color: #000000;
# }
# #T_f05fa_row2_col6 {
#   background-color: #d5d5e9;
#   color: #000000;
# }
# #T_f05fa_row3_col0 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_f05fa_row3_col1 {
#   background-color: #b01217;
#   color: #f1f1f1;
# }
# #T_f05fa_row3_col2, #T_f05fa_row9_col2 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_f05fa_row3_col3 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_f05fa_row3_col4 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_f05fa_row3_col5 {
#   background-color: #d3eecd;
#   color: #000000;
# }
# #T_f05fa_row3_col6 {
#   background-color: #e0e0ee;
#   color: #000000;
# }
# #T_f05fa_row4_col0, #T_f05fa_row5_col0 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_f05fa_row4_col1 {
#   background-color: #fee8de;
#   color: #000000;
# }
# #T_f05fa_row4_col2 {
#   background-color: #feeddb;
#   color: #000000;
# }
# #T_f05fa_row4_col3, #T_f05fa_row4_col4, #T_f05fa_row5_col3, #T_f05fa_row5_col4 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_f05fa_row4_col5 {
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_f05fa_row4_col6 {
#   background-color: #f5f4f9;
#   color: #000000;
# }
# #T_f05fa_row5_col1 {
#   background-color: #ffede5;
#   color: #000000;
# }
# #T_f05fa_row5_col2 {
#   background-color: #fee9d4;
#   color: #000000;
# }
# #T_f05fa_row5_col5 {
#   background-color: #eff9eb;
#   color: #000000;
# }
# #T_f05fa_row5_col6 {
#   background-color: #f6f5f9;
#   color: #000000;
# }
# #T_f05fa_row6_col0 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_f05fa_row6_col1 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_f05fa_row6_col2 {
#   background-color: #fee8d2;
#   color: #000000;
# }
# #T_f05fa_row6_col3, #T_f05fa_row6_col4 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_f05fa_row6_col5 {
#   background-color: #eff9ec;
#   color: #000000;
# }
# #T_f05fa_row6_col6 {
#   background-color: #f7f6fa;
#   color: #000000;
# }
# #T_f05fa_row7_col0 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_f05fa_row7_col1 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_f05fa_row7_col2 {
#   background-color: #fff1e4;
#   color: #000000;
# }
# #T_f05fa_row7_col3 {
#   background-color: #f2faf0;
#   color: #000000;
# }
# #T_f05fa_row7_col4 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_f05fa_row7_col5 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_f05fa_row7_col6 {
#   background-color: #faf8fb;
#   color: #000000;
# }
# #T_f05fa_row8_col0, #T_f05fa_row9_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_f05fa_row8_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_f05fa_row8_col2 {
#   background-color: #fff4e8;
#   color: #000000;
# }
# #T_f05fa_row8_col3, #T_f05fa_row8_col4, #T_f05fa_row9_col5 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_f05fa_row8_col5, #T_f05fa_row9_col3, #T_f05fa_row9_col4 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_f05fa_row8_col6 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_f05fa_row9_col1 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_f05fa_row9_col6 {
#   background-color: #fbfafc;
#   color: #000000;
# }
# </style>
# <table id="T_f05fa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f05fa_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_f05fa_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_f05fa_level0_col2" class="col_heading level0 col2" >min</th>
#       <th id="T_f05fa_level0_col3" class="col_heading level0 col3" >25%</th>
#       <th id="T_f05fa_level0_col4" class="col_heading level0 col4" >50%</th>
#       <th id="T_f05fa_level0_col5" class="col_heading level0 col5" >75%</th>
#       <th id="T_f05fa_level0_col6" class="col_heading level0 col6" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f05fa_level0_row0" class="row_heading level0 row0" >St. George</th>
#       <td id="T_f05fa_row0_col0" class="data row0 col0" >7,215</td>
#       <td id="T_f05fa_row0_col1" class="data row0 col1" >862</td>
#       <td id="T_f05fa_row0_col2" class="data row0 col2" >3,527</td>
#       <td id="T_f05fa_row0_col3" class="data row0 col3" >6,636</td>
#       <td id="T_f05fa_row0_col4" class="data row0 col4" >7,204</td>
#       <td id="T_f05fa_row0_col5" class="data row0 col5" >7,799</td>
#       <td id="T_f05fa_row0_col6" class="data row0 col6" >10,611</td>
#     </tr>
#     <tr>
#       <th id="T_f05fa_level0_row1" class="row_heading level0 row1" >St. Andrew</th>
#       <td id="T_f05fa_row1_col0" class="data row1 col0" >2,982</td>
#       <td id="T_f05fa_row1_col1" class="data row1 col1" >273</td>
#       <td id="T_f05fa_row1_col2" class="data row1 col2" >1,925</td>
#       <td id="T_f05fa_row1_col3" class="data row1 col3" >2,804</td>
#       <td id="T_f05fa_row1_col4" class="data row1 col4" >2,990</td>
#       <td id="T_f05fa_row1_col5" class="data row1 col5" >3,166</td>
#       <td id="T_f05fa_row1_col6" class="data row1 col6" >3,802</td>
#     </tr>
#     <tr>
#       <th id="T_f05fa_level0_row2" class="row_heading level0 row2" >St. Paul</th>
#       <td id="T_f05fa_row2_col0" class="data row2 col0" >1,213</td>
#       <td id="T_f05fa_row2_col1" class="data row2 col1" >512</td>
#       <td id="T_f05fa_row2_col2" class="data row2 col2" >631</td>
#       <td id="T_f05fa_row2_col3" class="data row2 col3" >828</td>
#       <td id="T_f05fa_row2_col4" class="data row2 col4" >888</td>
#       <td id="T_f05fa_row2_col5" class="data row2 col5" >1,717</td>
#       <td id="T_f05fa_row2_col6" class="data row2 col6" >2,975</td>
#     </tr>
#     <tr>
#       <th id="T_f05fa_level0_row3" class="row_heading level0 row3" >St. Patrick</th>
#       <td id="T_f05fa_row3_col0" class="data row3 col0" >1,079</td>
#       <td id="T_f05fa_row3_col1" class="data row3 col1" >722</td>
#       <td id="T_f05fa_row3_col2" class="data row3 col2" >31</td>
#       <td id="T_f05fa_row3_col3" class="data row3 col3" >172</td>
#       <td id="T_f05fa_row3_col4" class="data row3 col4" >1,406</td>
#       <td id="T_f05fa_row3_col5" class="data row3 col5" >1,663</td>
#       <td id="T_f05fa_row3_col6" class="data row3 col6" >2,364</td>
#     </tr>
#     <tr>
#       <th id="T_f05fa_level0_row4" class="row_heading level0 row4" >St. David</th>
#       <td id="T_f05fa_row4_col0" class="data row4 col0" >545</td>
#       <td id="T_f05fa_row4_col1" class="data row4 col1" >74</td>
#       <td id="T_f05fa_row4_col2" class="data row4 col2" >274</td>
#       <td id="T_f05fa_row4_col3" class="data row4 col3" >496</td>
#       <td id="T_f05fa_row4_col4" class="data row4 col4" >545</td>
#       <td id="T_f05fa_row4_col5" class="data row4 col5" >594</td>
#       <td id="T_f05fa_row4_col6" class="data row4 col6" >811</td>
#     </tr>
#     <tr>
#       <th id="T_f05fa_level0_row5" class="row_heading level0 row5" >St. John</th>
#       <td id="T_f05fa_row5_col0" class="data row5 col0" >533</td>
#       <td id="T_f05fa_row5_col1" class="data

# %%
# Get the number of new poor in each district
regions = outcomes['region'].unique().tolist()
n_regions = len(regions)
d = {}
for region in regions:
    df = outcomes[outcomes['region'] == region]
    d[region] = df['n_new_poor_increase_pp'].values.tolist()

# %%
# Make a coloured table
tab = pd.DataFrame(d).describe().T.sort_values('mean', ascending=False).round(2).drop('count', axis=1)
tab.style.background_gradient(cmap='Blues', subset=['mean'])\
         .background_gradient(cmap='Reds', subset=['std'])\
         .background_gradient(cmap='Oranges', subset=['min'])\
         .background_gradient(cmap='Greens', subset=['25%'])\
         .background_gradient(cmap='Greens', subset=['50%'])\
         .background_gradient(cmap='Greens', subset=['75%'])\
         .background_gradient(cmap='Purples', subset=['max'])\
         .format(decimal='.', thousands=',', precision=2)
# Out:
# <style type="text/css">
# #T_108f4_row0_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_108f4_row0_col1 {
#   background-color: #fb7151;
#   color: #f1f1f1;
# }
# #T_108f4_row0_col2 {
#   background-color: #e15307;
#   color: #f1f1f1;
# }
# #T_108f4_row0_col3, #T_108f4_row0_col4, #T_108f4_row0_col5 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_108f4_row0_col6 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_108f4_row1_col0 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_108f4_row1_col1 {
#   background-color: #fcbea5;
#   color: #000000;
# }
# #T_108f4_row1_col2 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_108f4_row1_col3 {
#   background-color: #006529;
#   color: #f1f1f1;
# }
# #T_108f4_row1_col4 {
#   background-color: #026f2e;
#   color: #f1f1f1;
# }
# #T_108f4_row1_col5 {
#   background-color: #0b7734;
#   color: #f1f1f1;
# }
# #T_108f4_row1_col6 {
#   background-color: #6e58a7;
#   color: #f1f1f1;
# }
# #T_108f4_row2_col0 {
#   background-color: #1966ad;
#   color: #f1f1f1;
# }
# #T_108f4_row2_col1 {
#   background-color: #fcae92;
#   color: #000000;
# }
# #T_108f4_row2_col2 {
#   background-color: #d94801;
#   color: #f1f1f1;
# }
# #T_108f4_row2_col3 {
#   background-color: #127c39;
#   color: #f1f1f1;
# }
# #T_108f4_row2_col4 {
#   background-color: #16803c;
#   color: #f1f1f1;
# }
# #T_108f4_row2_col5 {
#   background-color: #1c8540;
#   color: #f1f1f1;
# }
# #T_108f4_row2_col6 {
#   background-color: #7669af;
#   color: #f1f1f1;
# }
# #T_108f4_row3_col0 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_108f4_row3_col1 {
#   background-color: #d21f20;
#   color: #f1f1f1;
# }
# #T_108f4_row3_col2 {
#   background-color: #fdbf86;
#   color: #000000;
# }
# #T_108f4_row3_col3, #T_108f4_row3_col4 {
#   background-color: #bde5b6;
#   color: #000000;
# }
# #T_108f4_row3_col5 {
#   background-color: #65bd6f;
#   color: #f1f1f1;
# }
# #T_108f4_row3_col6 {
#   background-color: #7363ad;
#   color: #f1f1f1;
# }
# #T_108f4_row4_col0 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_108f4_row4_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_108f4_row4_col2 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_108f4_row4_col3 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_108f4_row4_col4 {
#   background-color: #84cc83;
#   color: #000000;
# }
# #T_108f4_row4_col5 {
#   background-color: #73c476;
#   color: #000000;
# }
# #T_108f4_row4_col6 {
#   background-color: #9793c5;
#   color: #f1f1f1;
# }
# #T_108f4_row5_col0 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_108f4_row5_col1 {
#   background-color: #fee1d4;
#   color: #000000;
# }
# #T_108f4_row5_col2 {
#   background-color: #fdb576;
#   color: #000000;
# }
# #T_108f4_row5_col3 {
#   background-color: #afdfa8;
#   color: #000000;
# }
# #T_108f4_row5_col4 {
#   background-color: #b1e0ab;
#   color: #000000;
# }
# #T_108f4_row5_col5 {
#   background-color: #b2e0ac;
#   color: #000000;
# }
# #T_108f4_row5_col6 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_108f4_row6_col0 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_108f4_row6_col1 {
#   background-color: #fedecf;
#   color: #000000;
# }
# #T_108f4_row6_col2 {
#   background-color: #fdd9b4;
#   color: #000000;
# }
# #T_108f4_row6_col3 {
#   background-color: #c6e8bf;
#   color: #000000;
# }
# #T_108f4_row6_col4, #T_108f4_row6_col5 {
#   background-color: #c4e8bd;
#   color: #000000;
# }
# #T_108f4_row6_col6 {
#   background-color: #dadaeb;
#   color: #000000;
# }
# #T_108f4_row7_col0 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_108f4_row7_col1 {
#   background-color: #fedfd0;
#   color: #000000;
# }
# #T_108f4_row7_col2 {
#   background-color: #feddbc;
#   color: #000000;
# }
# #T_108f4_row7_col3 {
#   background-color: #ceecc8;
#   color: #000000;
# }
# #T_108f4_row7_col4, #T_108f4_row7_col5 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_108f4_row7_col6 {
#   background-color: #ddddec;
#   color: #000000;
# }
# #T_108f4_row8_col0 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_108f4_row8_col1 {
#   background-color: #ac1117;
#   color: #f1f1f1;
# }
# #T_108f4_row8_col2 {
#   background-color: #ffefe0;
#   color: #000000;
# }
# #T_108f4_row8_col3 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_108f4_row8_col4 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_108f4_row8_col5 {
#   background-color: #95d391;
#   color: #000000;
# }
# #T_108f4_row8_col6 {
#   background-color: #bcbddc;
#   color: #000000;
# }
# #T_108f4_row9_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_108f4_row9_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_108f4_row9_col2 {
#   background-color: #fff2e6;
#   color: #000000;
# }
# #T_108f4_row9_col3, #T_108f4_row9_col4, #T_108f4_row9_col5 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_108f4_row9_col6 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_108f4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_108f4_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_108f4_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_108f4_level0_col2" class="col_heading level0 col2" >min</th>
#       <th id="T_108f4_level0_col3" class="col_heading level0 col3" >25%</th>
#       <th id="T_108f4_level0_col4" class="col_heading level0 col4" >50%</th>
#       <th id="T_108f4_level0_col5" class="col_heading level0 col5" >75%</th>
#       <th id="T_108f4_level0_col6" class="col_heading level0 col6" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_108f4_level0_row0" class="row_heading level0 row0" >St. George</th>
#       <td id="T_108f4_row0_col0" class="data row0 col0" >7.99</td>
#       <td id="T_108f4_row0_col1" class="data row0 col1" >0.95</td>
#       <td id="T_108f4_row0_col2" class="data row0 col2" >3.91</td>
#       <td id="T_108f4_row0_col3" class="data row0 col3" >7.35</td>
#       <td id="T_108f4_row0_col4" class="data row0 col4" >7.98</td>
#       <td id="T_108f4_row0_col5" class="data row0 col5" >8.64</td>
#       <td id="T_108f4_row0_col6" class="data row0 col6" >11.75</td>
#     </tr>
#     <tr>
#       <th id="T_108f4_level0_row1" class="row_heading level0 row1" >St. Luke</th>
#       <td id="T_108f4_row1_col0" class="data row1 col0" >6.93</td>
#       <td id="T_108f4_row1_col1" class="data row1 col1" >0.49</td>
#       <td id="T_108f4_row1_col2" class="data row1 col2" >5.47</td>
#       <td id="T_108f4_row1_col3" class="data row1 col3" >6.61</td>
#       <td id="T_108f4_row1_col4" class="data row1 col4" >6.95</td>
#       <td id="T_108f4_row1_col5" class="data row1 col5" >7.28</td>
#       <td id="T_108f4_row1_col6" class="data row1 col6" >8.69</td>
#     </tr>
#     <tr>
#       <th id="T_108f4_level0_row2" class="row_heading level0 row2" >St. Andrew</th>
#       <td id="T_108f4_row2_col0" class="data row2 col0" >6.39</td>
#       <td id="T_108f4_row2_col1" class="data row2 col1" >0.59</td>
#       <td id="T_108f4_row2_col2" class="data row2 col2" >4.12</td>
#       <td id="T_108f4_row2_col3" class="data row2 col3" >6.01</td>
#       <td id="T_108f4_row2_col4" class="data row2 col4" >6.41</td>
#       <td id="T_108f4_row2_col5" class="data row2 col5" >6.78</td>
#       <td id="T_108f4_row2_col6" class="data row2 col6" >8.15</td>
#     </tr>
#     <tr>
#       <th id="T_108f4_level0_row3" class="row_heading level0 row3" >St. Paul</th>
#       <td id="T_108f4_row3_col0" class="data row3 col0" >3.40</td>
#       <td id="T_108f4_row3_col1" class="data row3 col1" >1.43</td>
#       <td id="T_108f4_row3_col2" class="data row3 col2" >1.77</td>
#       <td id="T_108f4_row3_col3" class="data row3 col3" >2.32</td>
#       <td id="T_108f4_row3_col4" class="data row3 col4" >2.49</td>
#       <td id="T_108f4_row3_col5" class="data row3 col5" >4.81</td>
#       <td id="T_108f4_row3_col6" class="data row3 col6" >8.33</td>
#     </tr>
#     <tr>
#       <th id="T_108f4_level0_row4" class="row_heading level0 row4" >St. Patrick</th>
#       <td id="T_108f4_row4_col0" class="data row4 col0" >2.93</td>
#       <td id="T_108f4_row4_col1" class="data row4 col1" >1.96</td>
#       <td id="T_108f4_row4_col2" class="data row4 col2" >0.08</td>
#       <td id="T_108f4_row4_col3" class="data row4 col3" >0.47</td>
#       <td id="T_108f4_row4_col4" class="data row4 col4" >3.82</td>
#       <td id="T_108f4_row4_col5" class="data row

# %% [markdown]
# ## Average vulnerability

# %%
# vulnerability_by_quintile = get_average_weighted_vulnerability(outcomes, quintile=True)
# vulnerability_by_quintile.T.style.format("{:.2f}")

# %%
# vulnerability_by_decile = get_average_weighted_vulnerability(outcomes, quintile=False)
# vulnerability_by_decile.T.style.format("{:.2f}")

# %% [markdown]
# ## Raincloud plots

# %% [markdown]
# Raincloud plot is a combination of a boxplot, a kernel density plot, and a dot plot. It is a great way to visualize the distribution of the data. Especially, when the distribution is skewed and you have a lot of data points.

# %%
outcomes['policy'] = 'None'
raincloud_plot(outcomes, savefig=savefig)

# %% [markdown]
# ## Outcomes spatially

# %% [markdown]
# Another way to visualize the outcomes is to use choropleth maps. These maps are useful when you have data that is aggregated by a geographic area. For example, if we have data on how many people became poor after a disaster in the districts of Saint Lucia, we could use a choropleth map to show these numbers.
#
# What is important to remember is that **these maps do not show the variance** within each district. Instead, they show the mean or median value for each district.

# %%
# Get the country shapefile and aggregated outcomes
aggregation = 'median'
country = 'Dominica'
aggregated_outcomes = get_spatial_outcomes(outcomes=outcomes, country=country, aggregation=aggregation)

# Convert to be in millions
aggregated_outcomes[['tot_exposed_asset', 'tot_consum_loss_npv', 'region_pml']] /= 1000000
aggregated_outcomes[['tot_exposed_asset', 'tot_consum_loss_npv', 'region_pml']] = aggregated_outcomes[['tot_exposed_asset', 'tot_consum_loss_npv', 'region_pml']].round(2)

# %%
k = 5
# column = 'annual_avg_consum_loss_pct'
# title = 'Ann. Av. Cons. Loss PC (%)'
# cmap = 'YlOrRd'
column = 'r'
title = 'Socio-Economic Resilience'
cmap = 'RdYlGn'
# column = 'pml_relative'
# title = 'PML (%)'

# cmap = 'RdYlGn'
scheme = 'fisher_jenks'
ax = aggregated_outcomes.plot(column=column, scheme=scheme, k=k, cmap=cmap, legend=True, figsize=(10,10), legend_kwds={"title":title, "loc" : "upper right"})
aggregated_outcomes.plot(ax=ax, color='none', edgecolor='black', linewidth=0.25)
ax.axis('off')
for idx, row in aggregated_outcomes.iterrows():
    ax.annotate(text=row['NAME'], xy=row['geometry'].centroid.coords[0], ha='center', fontsize=12)
plt.savefig('r.png', dpi=300, bbox_inches='tight', transparent=True)
if savefig:
    plt.savefig(figures_folder + f'soc_econ_res_map.png', dpi=300, bbox_inches='tight')

# %%
fig, ax = plt.subplots(ncols=3, figsize=(14,8))
k = 5
columns = ['region_pml', 'annual_avg_consum_loss_pct', 'r']
titles = ['PML ($M)', 'Annual Average Consumption Loss PC (%)', 'Socio-Economic Resilience']
cmaps = ['OrRd', 'OrRd', 'RdYlGn']

scheme = 'fisher_jenks'
for i, column in enumerate(columns):
    title = titles[i]
    cmap = cmaps[i]
    aggregated_outcomes.plot(column=column, scheme=scheme, k=k, cmap=cmap, legend=True, ax=ax[i], legend_kwds={"title":title, "loc" : "upper right"})
    aggregated_outcomes.plot(ax=ax[i], color='none', edgecolor='black', linewidth=0.25)
    ax[i].axis('off')
    for idx, row in aggregated_outcomes.iterrows():
        ax[i].annotate(text=row['NAME'], xy=row['geometry'].centroid.coords[0], ha='center', fontsize=12)
plt.tight_layout()
if savefig:
    plt.savefig(figures_folder + f'soc_econ_res_map.png', dpi=300, bbox_inches='tight')

# %%
fig, ax = plt.subplots(ncols=3, nrows=2, figsize=(20, 14))

outcomes_to_plot = [
    'tot_exposed_asset',
    'total_consumption_loss',
    'annual_average_consumption_loss_pct',
    'n_new_poor_increase_pp',
    'r',
    'new_poverty_gap_all']

titles = ['Total exposed asset stock (MM)',
          'Total consumption loss (MM)',
          # 'Wt. Ann. Avg. Consump. Loss p.c. (%)',
          'Annual Average Consumption Loss PC (%)',
          'New Poor Increase (p.p.)',
          'Socio-Economic Resilience',
          'New Poverty Gap All Poor']

cmaps = ['OrRd', 'YlOrRd', 'OrRd', 'RdYlGn_r', 'RdYlGn', 'OrRd']

k = 4
for i, outcome in enumerate(outcomes_to_plot):
    aggregated_outcomes.plot(column=outcome, scheme='fisher_jenks', cmap=cmaps[i], k=k, ax=ax[i//3, i % 3], legend=True, legend_kwds={"loc": "upper left"})
    aggregated_outcomes.plot(ax=ax[i//3, i % 3], color='none', edgecolor='black', linewidth=0.25)
    ax[i//3, i % 3].set_title(titles[i])
    ax[i//3, i % 3].axis('off')
    for idx, row in aggregated_outcomes.iterrows():
        ax[i//3, i % 3].annotate(text=row['NAME'], xy=row['geometry'].centroid.coords[0], ha='center', fontsize=8)

# fig.suptitle(f'{aggregation.capitalize()} of 3,000 replications', fontsize=16)

fig.tight_layout()
if savefig:
    plt.savefig(figures_folder +
        f'{aggregation}_outcomes_spatially.png', dpi=300, bbox_inches='tight')

# %% [markdown]
# A bivariate or bi-variate choropleth helps to visualise relations between two variables spatially.

# %%
# Load asset damage data
# asset_damage = pd.read_excel('../data/processed/asset_damage/Saint Lucia.xlsx')
# asset_damage['district'].replace({'AnseLaRayeCanaries' : 'Anse-La-Raye & Canaries'}, inplace=True)
# gdf = pd.merge(aggregated_outcomes, asset_damage, left_on='NAME_1', right_on='district', how='left')

# %%
# x_name = 'r'
# y_name = 'pml'
# x_label = 'Soc.-econ. res.'
# y_label = 'PML'

# tab = bivariate_choropleth(gdf.copy(), x_name, y_name, x_label, y_label, scheme='fisher_jenks', figsize=(7,6), return_table=True)
# if savefig:
#     plt.savefig('../reports/figures/analysis/bivariate_choropleth.png', dpi=300, bbox_inches='tight')

# %%
# nine_quadrants_plot(gdf.copy(), x_name, y_name)
# plt.xlabel('Socio-Economic Resilience')
# plt.ylabel('PML')
# if savefig:
#     plt.savefig('../reports/figures/analysis/9_quadrants.png', dpi=300, bbox_inches='tight')
